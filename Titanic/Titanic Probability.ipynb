# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

df = pd.read_csv('titanic.csv')
df = df.drop(['PassengerId'], axis=1)
# genders = {"male": 1, "female": 0}
# df['Sex'] = df['Sex'].map(genders)

children = df[df['Age'] < 16]
children.shape # number of rows and column
children.hist(figsize=(20, 10))

living_children = df[(df['Age'] < 16) & (df['Survived'] == 1)]
living_children.hist(figsize=(20, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe4174c4f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe418c17ed0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe418c4cb90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe418c8cf10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe418cc1bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe418d03f50>]],
#       dtype=object)

# %%
not_surviving_children = df[(df['Age'] < 16) & (df['Survived'] == 0)]
not_surviving_children
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 63            64         0       3                    Skoog, Master. Harald
# 111          112         0       3                     Zabour, Miss. Hileni
# 119          120         0       3        Andersson, Miss. Ellis Anna Maria
# 147          148         0       3         Ford, Miss. Robina Maggie "Ruby"
# 164          165         0       3             Panula, Master. Eino Viljami
# 171          172         0       3                     Rice, Master. Arthur
# 182          183         0       3    Asplund, Master. Clarence Gustaf Hugo
# 205          206         0       3               Strom, Miss. Telma Matilda
# 278          279         0       3                       Rice, Master. Eric
# 297          298         0       1             Allison, Miss. Helen Loraine
# 352          353         0       3                       Elias, Mr. Tannous
# 374          375         0       3               Palsson, Miss. Stina Viola
# 386          387         0       3          Goodwin, Master. Sidney Leonard
# 419          420         0       3                Van Impe, Miss. Catharina
# 480          481         0       3           Goodwin, Master. Harold Victor
# 541          542         0       3     Andersson, Miss. Ingeborg Constanzia
# 542          543         0       3        Andersson, Miss. Sigrid Elisabeth
# 634          635         0       3                       Skoog, Miss. Mabel
# 642          643         0       3            Skoog, Miss. Margit Elizabeth
# 683          684         0       3              Goodwin, Mr. Charles Edward
# 686          687         0       3                 Panula, Mr. Jaako Arnold
# 731          732         0       3                 Hassan, Mr. Houssein G N
# 787          788         0       3                Rice, Master. George Hugh
# 813          814         0       3       Andersson, Miss. Ebba Iris Alfrida
# 819          820         0       3             Skoog, Master. Karl Thorsten
# 824          825         0       3             Panula, Master. Urho Abraham
# 850          851         0       3  Andersson, Master. Sigvard Harald Elias
# 852          853         0       3                  Boulos, Miss. Nourelain
#
#         Sex   Age  SibSp  Parch      Ticket      Fare    Cabin Embarked
# 7      male   2.0      3      1      349909   21.0750      NaN        S
# 14   female  14.0      0      0      350406    7.8542      NaN        S
# 16     male   2.0      4      1      382652   29.1250      NaN        Q
# 24   female   8.0      3      1      349909   21.0750      NaN        S
# 50     male   7.0      4      1     3101295   39.6875      NaN        S
# 59     male  11.0      5      2     CA 2144   46.9000      NaN        S
# 63     male   4.0      3      2      347088   27.9000      NaN        S
# 111  female  14.5      1      0        2665   14.4542      NaN        C
# 119  female   2.0      4      2      347082   31.2750      NaN        S
# 147  female   9.0      2      2  W./C. 6608   34.3750      NaN        S
# 164    male   1.0      4      1     3101295   39.6875      NaN        S
# 171    male   4.0      4      1      382652   29.1250      NaN        Q
# 182    male   9.0      4      2      347077   31.3875      NaN        S
# 205  female   2.0      0      1      347054   10.4625       G6        S
# 278    male   7.0      4      1      382652   29.1250      NaN        Q
# 297  female   2.0      1      2      113781  151.5500  C22 C26        S
# 352    male  15.0      1      1        2695    7.2292      NaN        C
# 374  female   3.0      3      1      349909   21.0750      NaN        S
# 386    male   1.0      5      2     CA 2144   46.9000      NaN        S
# 419  female  10.0      0      2      345773   24.1500      NaN        S
# 480    male   9.0      5      2     CA 2144   46.9000      NaN        S
# 541  female   9.0      4      2      347082   31.2750      NaN        S
# 542  female  11.0      4      2      347082   31.2750      NaN        S
# 634  female   9.0      3      2      347088   27.9000      NaN        S
# 642  female   2.0      3      2      347088   27.9000      NaN        S
# 683    male  14.0      5      2     CA 2144   46.9000      NaN        S
# 686    male  14.0      4      1     3101295   39.6875      NaN        S
# 731    male  11.0      0      0        2699   18.7875      NaN        C
# 787    male   8.0      4      1      382652   29.1250      NaN        Q
# 813  female   6.0      4      2      347082   31.2750      NaN        S
# 819    male  10.0      3      2      347088   27.9000      NaN        S
# 824    male   2.0      4      1     3101295   39.6875      NaN        S
# 850    male   4.0      4      2      347082   31.2750      NaN        S
# 852  female   9.0      1      1        2678   15.2458      NaN        C

# %%
not_surviving_children = df[(df['Age'] < 16) & (df['Survived'] == 0)]
not_surviving_children

living_children.hist(figsize=(20, 10))

not_surviving_children.hist(figsize=(20, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fe419b8cc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe417a458d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe417ed6590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe417aa2450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fe417ec0750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe418bc1b90>]],
#       dtype=object)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

df = pd.read_csv('titanic.csv')
df = df.drop(['PassengerId'], axis=1)
genders = {"male": 1, "female": 0}
df['Sex'] = df['Sex'].map(genders)

living_children = df[(df['Age'] < 16) & (df['Survived'] == 1)]
not_surviving_children = df[(df['Age'] < 16) & (df['Survived'] == 0)]
living_children.hist(figsize=(20, 10))
not_surviving_children.hist(figsize=(20, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f942bfa9ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f942c29e450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f942635e510>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f942d9ac750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f940e43b950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f940e45e410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f940e49d150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f942c1d39d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f942c1cf550>]],
#       dtype=object)

# %%
women_and_children = df[(df['Sex'] == "female") | (df['Age'] < 16)]
w_a_c_survival_rate = women_and_children['Survived'].value_counts(normalize=True) * 100
w_a_c_survival_rate
# Out:
# 1    71.751412
# 0    28.248588
# Name: Survived, dtype: float64

# %%
adult_men = df[(df['Sex'].str.match('male')) & (df['Age'] > 16)]
a_m_survival_rate = adult_men['Survived'].value_counts(normalize=True) * 100
a_m_survival_rate
# Out:
# 0    82.338308
# 1    17.661692
# Name: Survived, dtype: float64

# %%
children = df[df['Age'] < 16]
surviving_children = df[(df['Age'] < 16) & (df['Survived'] == 1)]
child_chance_of_survival = surviving_children.shape[0] / children.shape[0]
print(child_chance_of_survival)
format(child_chance_of_survival, ".0%")
# Out:
# 0.5903614457831325
# '59%'

# %%
women = df[(df['Sex'] == 'female') & (df['Age'] > 16)]
surviving_women = df[(df['Sex'] == 'female') & (df['Age'] > 16) & (df['Survived'] == 1)]
women_chance_of_survival = surviving_women.shape[0] / women.shape[0]
format(women_chance_of_survival, ".0%")
# Out:
# '77%'

# %%
import matplotlib.pyplot as plt

men_chance_of_survival = a_m_survival_rate[1] / 100

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
x_axis = ["Children", "Women", "Men"]
data = [child_chance_of_survival, women_chance_of_survival, men_chance_of_survival]
ax.bar(x_axis, data)
plt.show()

# %%
female_and_class = df[(df['Sex'] == 'female') & (df['Pclass']) & (df['Survived'] == 1)]
female_and_class.hist(figsize=(20, 10))

male_and_class = df[(df['Sex'] == 'male') & (df['Pclass']) & (df['Survived'] == 1)]
male_and_class.hist(figsize=(20, 10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9413b3dd90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f941400cf50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9414040c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9414081f90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f94140b8c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94140f7fd0>]],
#       dtype=object)

# %%
surviving_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Survived'] == 1)]
surviving_men.describe()
# Out:
#        Survived     Pclass        Age      SibSp      Parch        Fare
# count      71.0  71.000000  71.000000  71.000000  71.000000   71.000000
# mean        1.0   1.873239  34.323944   0.267606   0.126761   46.731869
# std         0.0   0.955130  11.798032   0.476827   0.411602   85.316448
# min         1.0   1.000000  17.000000   0.000000   0.000000    0.000000
# 25%         1.0   1.000000  26.500000   0.000000   0.000000    8.050000
# 50%         1.0   1.000000  32.000000   0.000000   0.000000   26.550000
# 75%         1.0   3.000000  41.000000   0.500000   0.000000   54.270850
# max         1.0   3.000000  80.000000   2.000000   2.000000  512.329200

# %%
dead_men = df[(df['Sex'] == "male") & (df['Age'] > 16) & (df['Survived'] == 0)]
dead_men.describe()
# Out:
#        Survived      Pclass         Age       SibSp       Parch        Fare
# count     331.0  331.000000  331.000000  331.000000  331.000000  331.000000
# mean        0.0    2.383686   33.496979    0.250755    0.166163   22.562523
# std         0.0    0.779028   12.970596    0.516947    0.566384   33.570494
# min         0.0    1.000000   17.000000    0.000000    0.000000    0.000000
# 25%         0.0    2.000000   23.000000    0.000000    0.000000    7.854200
# 50%         0.0    3.000000   30.000000    0.000000    0.000000   10.170800
# 75%         0.0    3.000000   40.500000    0.000000    0.000000   26.000000
# max         0.0    3.000000   74.000000    3.000000    5.000000  263.000000

# %%
the_dead = df[df["Survived"] == 0]
the_dead.hist(figsize=(10, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f941474f450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f941355e290>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f9413f49710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f94142c32d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f941427d550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f9413b450d0>]],
#       dtype=object)

# %%
import seaborn as sn
sn.barplot(x='Pclass', y='Survived', data=women)

# %%
sn.barplot(x='Pclass', y='Survived', hue="Sex", data=df)

# %%
sn.barplot(x='Sex', y='Survived', hue="Pclass", data=df)

# %%
# create a list of Age values not including N/A values
ls_age = df['Age'].dropna()
# Now plot the data in this list into a histogram!
sn.distplot(ls_age, hist=True, kde=False, bins=16)

# %%
# Notice only the KDE parameter is different!
# What does kde stand for? https://seaborn.pydata.org/generated/seaborn.distplot.html
sn.distplot(df['Age'].dropna(), hist=True, kde=True, bins=16)

# %%
sn.distplot(df['Age'].dropna(), hist_kws=dict(cumulative=True), kde_kws=dict(cumulative=True))
